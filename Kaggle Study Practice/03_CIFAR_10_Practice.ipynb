# %% [markdown]
# <a href="https://colab.research.google.com/github/wjdwogns2873-web/deep-learning-study/blob/main/Kaggle%20Study%20Practice/03_CIFAR_10_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# Out:
# 100%|██████████| 170M/170M [00:04<00:00, 42.1MB/s]

# %%
print(trainset.data.shape)
image, label = trainset[0]
print(image.shape)
# Out:
# (50000, 32, 32, 3)
# torch.Size([3, 32, 32])

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.data import DataLoader

classes = ('airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

BATCH_SIZE = 8
transform = transforms.ToTensor()
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=False, transform=transform)
trainloader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)

def imshow(img):
    npimg = img.numpy()
    # print(npimg.shape)
    plt.figure(figsize=(12, 6))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    plt.show()

dataiter = iter(trainloader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images, nrow=len(labels)))
print("정답 라벨: ", ' | '.join(f'{classes[labels[j]]}' for j in range(len(labels))))
# Out:
# <class 'tuple'> <class 'str'>
# (3, 36, 274)
# (36, 274, 3)
# 정답 라벨:  dog | bird | airplane | dog | cat | cat | dog | frog

# %%
import torch.nn as nn
import torch.nn.functional as F

class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.fc = nn.Linear(16 * 16 * 16, 10)
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# %%
import torch.optim as optim
model = SimpleCNN()

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 3

for epoch in range(epochs):
    running_loss = 0.0
    for i, data in enumerate(trainloader):
        images, labels = data

        optimizer.zero_grad()
        outputs = model(images)
        # print(outputs.shape) # (8, 10) 예상. 배치 사이즈 8, out channels 10
        loss = criterion(outputs, labels)
        # print(type(loss)) # <class 'torch.Tensor'>
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        if (i + 1) % 2000 == 0:
            print(f"Epoch {epoch+1} | Batch {i+1} | Loss: {running_loss / 2000:.4f}")
            running_loss = 0.0
# Out:
# Epoch 1 | Batch 2000 | Loss: 1.4979
# Epoch 1 | Batch 4000 | Loss: 1.3806
# Epoch 1 | Batch 6000 | Loss: 1.3211
# Epoch 2 | Batch 2000 | Loss: 1.2298
# Epoch 2 | Batch 4000 | Loss: 1.2090
# Epoch 2 | Batch 6000 | Loss: 1.1891
# Epoch 3 | Batch 2000 | Loss: 1.1150
# Epoch 3 | Batch 4000 | Loss: 1.1314
# Epoch 3 | Batch 6000 | Loss: 1.1260

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

trainset.transform = train_transform

# %%
class DeepCNN(nn.Module):
    def __init__(self):
        super().__init__()
        # (8, 3, 32, 32) (batch size, channels, height, width)
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1) # (8, 32, 32, 32)
        self.bn1 = nn.BatchNorm2d(32)

        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1) # (8, 64, 16, 16) after pooling
        self.bn2 = nn.BatchNorm2d(64)

        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1) # (8, 128, 8, 8) after pooling
        self.bn3 = nn.BatchNorm2d(128)

        self.pool = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(128 * 4 * 4, 512)
        self.fc2 = nn.Linear(512, 10)

        self.dropout = nn.Dropout(0.2)
    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = self.pool(F.relu(self.bn3(self.conv3(x))))

        x = x.view(x.size(0), -1) # (8, 128 * 4 * 4)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
model = DeepCNN()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
epochs = 3

for epoch in range(epochs):
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        images, labels = data
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        if (i+1) % 200 == 0:
            print(f"Epoch {epoch+1} | Batch {i+1} | Loss: {running_loss / 200:.4f}")
            running_loss = 0.0
# Out:
# Epoch 1 | Batch 200 | Loss: 2.1864
# Epoch 1 | Batch 400 | Loss: 1.9263
# Epoch 1 | Batch 600 | Loss: 1.8927
# Epoch 1 | Batch 800 | Loss: 1.7871
# Epoch 1 | Batch 1000 | Loss: 1.7458
# Epoch 1 | Batch 1200 | Loss: 1.7453
# Epoch 1 | Batch 1400 | Loss: 1.7238
# Epoch 1 | Batch 1600 | Loss: 1.7002
# Epoch 1 | Batch 1800 | Loss: 1.6221
# Epoch 1 | Batch 2000 | Loss: 1.6784
# Epoch 1 | Batch 2200 | Loss: 1.5978
# Epoch 1 | Batch 2400 | Loss: 1.5513
# Epoch 1 | Batch 2600 | Loss: 1.5631
# Epoch 1 | Batch 2800 | Loss: 1.5373
# Epoch 1 | Batch 3000 | Loss: 1.5756
# Epoch 1 | Batch 3200 | Loss: 1.5197
# Epoch 1 | Batch 3400 | Loss: 1.5055
# Epoch 1 | Batch 3600 | Loss: 1.4465
# Epoch 1 | Batch 3800 | Loss: 1.4713
# Epoch 1 | Batch 4000 | Loss: 1.4839
# Epoch 1 | Batch 4200 | Loss: 1.4346
# Epoch 1 | Batch 4400 | Loss: 1.4146
# Epoch 1 | Batch 4600 | Loss: 1.4588
# Epoch 1 | Batch 4800 | Loss: 1.4019
# Epoch 1 | Batch 5000 | Loss: 1.4165
# Epoch 1 | Batch 5200 | Loss: 1.3884
# Epoch 1 | Batch 5400 | Loss: 1.3591
# Epoch 1 | Batch 5600 | Loss: 1.4228
# Epoch 1 | Batch 5800 | Loss: 1.3107
# Epoch 1 | Batch 6000 | Loss: 1.3349
# Epoch 1 | Batch 6200 | Loss: 1.3421
# Epoch 2 | Batch 200 | Loss: 1.2716
# Epoch 2 | Batch 400 | Loss: 1.3192
# Epoch 2 | Batch 600 | Loss: 1.2854
# Epoch 2 | Batch 800 | Loss: 1.2748
# Epoch 2 | Batch 1000 | Loss: 1.2788
# Epoch 2 | Batch 1200 | Loss: 1.2798
# Epoch 2 | Batch 1400 | Loss: 1.2428
# Epoch 2 | Batch 1600 | Loss: 1.2696
# Epoch 2 | Batch 1800 | Loss: 1.2782
# Epoch 2 | Batch 2000 | Loss: 1.2139
# Epoch 2 | Batch 2200 | Loss: 1.2132
# Epoch 2 | Batch 2400 | Loss: 1.2689
# Epoch 2 | Batch 2600 | Loss: 1.1956
# Epoch 2 | Batch 2800 | Loss: 1.2075
# Epoch 2 | Batch 3000 | Loss: 1.2019
# Epoch 2 | Batch 3200 | Loss: 1.1881
# Epoch 2 | Batch 3400 | Loss: 1.2136
# Epoch 2 | Batch 3600 | Loss: 1.1422
# Epoch 2 | Batch 3800 | Loss: 1.1143
# Epoch 2 | Batch 4000 | Loss: 1.1345
# Epoch 2 | Batch 4200 | Loss: 1.1829
# Epoch 2 | Batch 4400 | Loss: 1.0949
# Epoch 2 | Batch 4600 | Loss: 1.1685
# Epoch 2 | Batch 4800 | Loss: 1.0830
# Epoch 2 | Batch 5000 | Loss: 1.1562
# Epoch 2 | Batch 5200 | Loss: 1.1222
# Epoch 2 | Batch 5400 | Loss: 1.1394
# Epoch 2 | Batch 5600 | Loss: 1.1889
# Epoch 2 | Batch 5800 | Loss: 1.0915
# Epoch 2 | Batch 6000 | Loss: 1.0561
# Epoch 2 | Batch 6200 | Loss: 1.1080
# Epoch 3 | Batch 200 | Loss: 1.0573
# Epoch 3 | Batch 400 | Loss: 1.0867
# Epoch 3 | Batch 600 | Loss: 1.0548
# Epoch 3 | Batch 800 | Loss: 1.0423
# Epoch 3 | Batch 1000 | Loss: 1.0413
# Epoch 3 | Batch 1200 | Loss: 1.0916
# Epoch 3 | Batch 1400 | Loss: 1.0590
# Epoch 3 | Batch 1600 | Loss: 1.0817
# Epoch 3 | Batch 1800 | Loss: 1.0668
# Epoch 3 | Batch 2000 | Loss: 1.0488
# Epoch 3 | Batch 2200 | Loss: 1.0778
# Epoch 3 | Batch 2400 | Loss: 1.0141
# Epoch 3 | Batch 2600 | Loss: 1.0550
# Epoch 3 | Batch 2800 | Loss: 1.0621
# Epoch 3 | Batch 3000 | Loss: 1.0418
# Epoch 3 | Batch 3200 | Loss: 1.0501
# Epoch 3 | Batch 3400 | Loss: 1.0265
# Epoch 3 | Batch 3600 | Loss: 0.9979
# Epoch 3 | Batch 3800 | Loss: 1.0299
# Epoch 3 | Batch 4000 | Loss: 0.9956
# Epoch 3 | Batch 4200 | Loss: 0.9841
# Epoch 3 | Batch 4400 | Loss: 1.0381
# Epoch 3 | Batch 4600 | Loss: 1.0015
# Epoch 3 | Batch 4800 | Loss: 1.0106
# Epoch 3 | Batch 5000 | Loss: 0.9566
# Epoch 3 | Batch 5200 | Loss: 1.0400
# Epoch 3 | Batch 5400 | Loss: 1.0219
# Epoch 3 | Batch 5600 | Loss: 1.0165
# Epoch 3 | Batch 5800 | Loss: 1.0374
# Epoch 3 | Batch 6000 | Loss: 0.9660
# Epoch 3 | Batch 6200 | Loss: 0.9700
